# %%
import numpy as np
import plotly.graph_objects as go
import os
import sys

# %%
# Add the parent directory to sys.path
sys.path.append(os.path.join(os.path.abspath(''), ".."))
from nwave import *

# %%
def func1(x):
    k1 = 11.0
    k2 = 7.0
    f = np.cos(x) + np.sin(k1 * x)
    dxf = k1 * np.cos(k1 * x) - np.sin(x)
    dxxf = -np.cos(x) - k1**2 * np.sin(k1 * x)
    return f, dxf, dxxf


def func2(x):
    """Simpler test for testing 'symmetry' to make sure x and y give the same values"""
    freq = (1.0 / 2.0) * np.pi
    f = np.cos(freq * x)

    # first order analytical derivative
    dxf = -freq * np.sin(freq * x)

    # second order analytical derivative
    dxxf = -freq * freq * np.cos(freq * x)

    return f, dxf, dxxf

def func3(x):
    """Test function similar to BSSN variables"""
    epsilon = 1.72345769e-5
    f = -2/(x + epsilon)
    dxf = 2 / ((x + epsilon) ** 2)
    dxxf = -4 / ((x + epsilon) ** 3)
    return f, dxf, dxxf

def func4(r, a):
    f = np.empty_like(r)
    dxf = np.empty_like(r)
    dxxf = np.empty_like(r)
    for i in range(len(r)):
        if r[i] < 0.0:
            f[i] = 2.0/(a**2 - r[i])
            dxf[i] = 2.0/(a**2 - r[i])**2
            dxxf[i] = 4.0/(a**2 - r[i])**3
        else:
            f[i] = -2.0/(a**2 + r[i])
            dxf[i] = 2.0/(a**2 + r[i])**2
            dxxf[i] = -4.0/(a**2 + r[i])**3

    return f, dxf, dxxf

# %%
nx0 = 12
level = 6
nx = int((2**level)*nx0 + 1)
params = { "Nx": nx, "Xmin": -10.0, "Xmax": 10.0 }

g = Grid1D(params)
dx = g.dx[0]
x = g.xi[0]

nBH = int(1/dx)
print(f"Grid size: {nx}, dx: {dx}, resolution at BH: {nBH}")
# Out:
# Grid1D: nx=769, xmin=-10.0, xmax=10.0, dx=0.026041666666666668, ng=0 cell_centered=False
# Grid size: 769, dx: 0.026041666666666668, resolution at BH: 38

# %%
derivs = [ 
    DerivType.D1_KP4,
    DerivType.D1_ME44,
    DerivType.D1_ME642,
    DerivType.D1_JT4,
    DerivType.D1_JT6,
    DerivType.D1_JP6,
    DerivType.D1_DSQ6A,
    DerivType.D1_DSQ6B,
    DerivType.D1_DSQ6B_LEFT,
    DerivType.D1_DSQ6B_RIGHT
]
dnames = [ 
    "D1_KP4",
    "D1_ME44",
    "D1_ME642",
    "D1_JT4",
    "D1_JT6",
    "D1_JP6",
    "D1_DSQ6A",
    "D1_DSQ6B",
    "D1_DSQ6B_LEFT",
    "D1_DSQ6B_RIGHT"
]

derivs2 = [
    DerivType.D2_ME44,
    DerivType.D2_ME642,
    DerivType.D2_JT4,
    DerivType.D2_JP6,
    DerivType.D2_DSQ6A,
    DerivType.D2_DSQ6B
]

dnames2 = [
    "D2_ME44",
    "D2_ME642",
    "D2_JT4",
    "D2_JP6",
    "D2_DSQ6A",
    "D2_DSQ6B"
]

# %%
f, dxf, dxxf = func4(x, 1.0e-3)

# %%
# create data files
d1_data = []

for dd, dn in zip(derivs, dnames):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.deriv(x, dd, CFDSolve.SCIPY)
    CDxf = CD.grad(f)
    err = np.abs(CDxf - dxf)
    d1_data.append([dn, CDxf, err])
# Out:
# ...constructing D1_KP4
# ...constructing D1_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME44.  Using D_LU instead.
# ...constructing D1_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME642.  Using D_LU instead.
# ...constructing D1_JT4
# ...constructing D1_JT6
# ...constructing D1_JP6
# ...constructing D1_DSQ6A
# ...constructing D1_DSQ6B
# ...constructing D1_DSQ6B_LEFT
# ...constructing D1_DSQ6B_RIGHT

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d1_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Derivative Error Plots (dxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_KP4',
#               'type': 'scatter',
#               'uid': '17369fa7-20c3-48c4-9d41-5f661feb1bc9',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAEL3tT0AAAAAbh2TPQAAAABk1Y' ... 'AAVMOAPQAAAAD/B5M9AAAAACbitT0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME44',
#               'type': 'scatter',
#               'uid': '551049fa-ec0e-45eb-bd48-2aaa441e17e2',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAwKfruD0AAAAALPyYPQAAAACPsZ' ... 'AAW7CQPZ/qCOtKlqQ/OA7EAuF6pD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME642',
#               'type': 'scatter',
#               'uid': 'e49786a3-4b54-477f-b709-3fd4ca0c5131',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADSnvdYkj4AAMAcO2WCPgAAAACPsZ' ... 'wC7LGkP7gzS4RPlqQ/0hV61td6pD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT4',
#               'type': 'scatter',
#               'uid': '6fe9bc31-5b8f-49dc-bcc2-81fee2c98db6',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAwCVJsj0AAAAAkSOQPQAAAABIVX' ... 'AAIEl/PQAAAAAxHJA9AAAAgFBEsj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT6',
#               'type': 'scatter',
#               'uid': '85418f86-ab7a-41b5-a281-b68ee3781a64',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAABXFz0AAAAAAPjmPAAAAAAAeO' ... 'AAADIEPQAAAAAAbBI9AAAAAABsNj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JP6',
#               'type': 'scatter',
#               'uid': 'c98f3b16-9890-42bb-abe1-0f33a95562c5',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('gCXguOQXVD8AZkSbSmgsPwBBslu6Kx' ... '5buisWPwCbQJtKaCw/cBffuOQXVD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6A',
#               'type': 'scatter',
#               'uid': 'ab6c0c1e-2fb6-4006-aa34-43e8f039d4ab',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAG4cO2WCPgAAAAA9sZ' ... 'AAu7CQPQAAEBo7ZYI+AAANofdYkj4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B',
#               'type': 'scatter',
#               'uid': '400f53cb-d0cf-4b2d-8545-37d0486b03cb',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAG4cO2WCPgAAAAA9sZ' ... 'AAu7CQPQAAEBo7ZYI+AAANofdYkj4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_LEFT',
#               'type': 'scatter',
#               'uid': 'e50cabac-2e78-4951-90a5-56fb416b61ea',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('zMsVSl2WpD8AAG4cO2WCPgBclyfc2B' ... 'on3NgbPwAAEBo7ZYI+sMoVSl2WpD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_RIGHT',
#               'type': 'scatter',
#               'uid': 'bf814172-a697-403c-8928-566f4dac5acb',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAKe2T4qSPgAAAADbX5' ... 'AA1GKZPQAAnrlPipI+AAANofdYkj4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Derivative Error Plots (dxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })

# %%
# create data files
d2_data = []

for dd, dn in zip(derivs2, dnames2):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.deriv(x, dd, CFDSolve.SCIPY)
    CDxxf = CD.grad(f)
    err = np.abs(CDxxf - dxxf)
    d2_data.append([dn, CDxxf, err])
# Out:
# ...constructing D2_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D2_ME44.  Using D_LU instead.
# ...constructing D2_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D2_ME642.  Using D_LU instead.
# ...constructing D2_JT4
# ...constructing D2_JP6
# ...constructing D2_DSQ6A
# ...constructing D2_DSQ6B

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d2_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Derivative Error Plots (dxxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_ME44',
#               'type': 'scatter',
#               'uid': '7b0dc12a-f99a-47f1-a8fb-8d86c05098c4',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAYCKlzD0AAADAzyWWPQAAAAAQE3' ... 'AA1kRtPQAAAEAi3pY9AAAASHRdzT0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_ME642',
#               'type': 'scatter',
#               'uid': '20e26c2a-72ff-4553-a2c0-80327fb450d4',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AACOPfJPlD4AAMgpd4JdPgAAAAAQE3' ... 'AA1kRtPQAAGAt6gl0+AMC2mfJPlD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_JT4',
#               'type': 'scatter',
#               'uid': 'f8a576f4-6f11-478c-96f7-44740c43815e',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAgBKTlz0AAAAA5m1qPQAAAAAQUV' ... 'AArI1YPQAAAAAsrJo9AAAAmLP5zz0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_JP6',
#               'type': 'scatter',
#               'uid': '5748a14a-7135-4bc8-875a-ace36a54f92c',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('IHou0M/cQD+AnpssMDEHPwAOfRyRX+' ... '4WkV/hPoBb1SswMQc/wM4G0M/cQD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_DSQ6A',
#               'type': 'scatter',
#               'uid': '09f3cb35-43d7-4a94-9b4b-4cc1fc12da1e',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AECfIPFPlD4AACgAe4JdPgAAAADcRm' ... 'AA/IVnPQAAXHZ4gl0+AEBMf/JPlD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_DSQ6B',
#               'type': 'scatter',
#               'uid': 'ddb9a339-b0a9-4599-beeb-2cc1045a4518',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AECfIPFPlD4AACgAe4JdPgAAAADcRm' ... 'AA/IVnPQAAXHZ4gl0+AEBMf/JPlD4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Derivative Error Plots (dxxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })

# %%
x_bh = 0.0
dx_bh = 0.15

d3_data = []

for dd, dn in zip(derivs, dnames):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.bh_deriv(x, dd, DerivType.D1_ME44, CFDSolve.SCIPY, x_bh, dx_bh)
    CDxf = CD.grad(f)
    err = np.abs(CDxf - dxf)
    d3_data.append([dn, CDxf, err])
# Out:
# ...constructing D1_KP4
# ...constructing D1_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME44.  Using D_LU instead.
# ...constructing D1_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME642.  Using D_LU instead.
# ...constructing D1_JT4
# ...constructing D1_JT6
# ...constructing D1_JP6
# ...constructing D1_DSQ6A
# ...constructing D1_DSQ6B
# ...constructing D1_DSQ6B_LEFT
# ...constructing D1_DSQ6B_RIGHT

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d3_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Masked BH Derivative Error Plots (dxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_KP4',
#               'type': 'scatter',
#               'uid': '184a6ac2-6e2c-45a4-bb6d-638fbe307a95',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAEL3tT0AAAAAbh2TPQAAAABk1Y' ... 'AAVMOAPQAAAAD/B5M9AAAAACbitT0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME44',
#               'type': 'scatter',
#               'uid': 'f0cd958b-af50-4ffb-a65c-dc1a712926f1',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAwKfruD0AAAAALPyYPQAAAACPsZ' ... 'AAW7CQPZ/qCOtKlqQ/OA7EAuF6pD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME642',
#               'type': 'scatter',
#               'uid': '5d3454a2-6fdb-4009-a0c2-3f5264a57366',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADSnvdYkj4AAMAcO2WCPgAAAACPsZ' ... 'wC7LGkP7gzS4RPlqQ/0hV61td6pD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT4',
#               'type': 'scatter',
#               'uid': '79c38b95-d749-48aa-9a68-97b9ec0820c6',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAwCVJsj0AAAAAkSOQPQAAAABIVX' ... 'AAIEl/PQAAAAAxHJA9AAAAgFBEsj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT6',
#               'type': 'scatter',
#               'uid': 'c28d2326-5da7-46ba-835c-346ba32e7176',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAABXFz0AAAAAAPjmPAAAAAAAeO' ... 'AAADIEPQAAAAAAbBI9AAAAAABsNj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JP6',
#               'type': 'scatter',
#               'uid': 'b6a53ec4-3fd8-4d3e-856c-ca19032c5cb5',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('gCXguOQXVD8AZkSbSmgsPwBBslu6Kx' ... '5buisWPwCbQJtKaCw/cBffuOQXVD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6A',
#               'type': 'scatter',
#               'uid': 'f882855a-47b7-46e7-bfe5-38f31e19f7dc',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAG4cO2WCPgAAAAA9sZ' ... 'AAu7CQPQAAEBo7ZYI+AAANofdYkj4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B',
#               'type': 'scatter',
#               'uid': 'dc9b3714-f5ce-457f-9df8-0119c064bdc1',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAG4cO2WCPgAAAAA9sZ' ... 'AAu7CQPQAAEBo7ZYI+AAANofdYkj4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_LEFT',
#               'type': 'scatter',
#               'uid': '4f173c14-369e-4508-8824-bf8c335b9254',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('zMsVSl2WpD8AAG4cO2WCPgBclyfc2B' ... 'on3NgbPwAAEBo7ZYI+sMoVSl2WpD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_RIGHT',
#               'type': 'scatter',
#               'uid': 'a1977a1c-85aa-4f70-bacb-1f58f74f3516',
#               'x': {'bdata': ('AAAAAAAAJMCrqqqqqvIjwFVVVVVV5S' ... 'VVVeUjQKyqqqqq8iNAAAAAAAAAJEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AABjoPdYkj4AAKe2T4qSPgAAAADbX5' ... 'AA1GKZPQAAnrlPipI+AAANofdYkj4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Masked BH Derivative Error Plots (dxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })
