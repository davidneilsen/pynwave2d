# %%
import numpy as np
import plotly.graph_objects as go
import os
import sys

# %%
# Add the parent directory to sys.path
sys.path.append(os.path.join(os.path.abspath(''), ".."))
from nwave import *

# %%
def func1(x):
    k1 = 11.0
    k2 = 7.0
    f = np.cos(x) + np.sin(k1 * x)
    dxf = k1 * np.cos(k1 * x) - np.sin(x)
    dxxf = -np.cos(x) - k1**2 * np.sin(k1 * x)
    return f, dxf, dxxf


def func2(x):
    """Simpler test for testing 'symmetry' to make sure x and y give the same values"""
    freq = (1.0 / 2.0) * np.pi
    f = np.cos(freq * x)

    # first order analytical derivative
    dxf = -freq * np.sin(freq * x)

    # second order analytical derivative
    dxxf = -freq * freq * np.cos(freq * x)

    return f, dxf, dxxf

def func3(x):
    """Test function similar to BSSN variables"""
    epsilon = 1.72345769e-5
    f = -2/(x + epsilon)
    dxf = 2 / ((x + epsilon) ** 2)
    dxxf = -4 / ((x + epsilon) ** 3)
    return f, dxf, dxxf

# %%
nx0 = 12
level = 6
nx = int((2**level)*nx0 + 1)
params = { "Nx": nx, "Xmin": -4.0, "Xmax": 4.0 }

g = Grid1D(params)
dx = g.dx[0]
x = g.xi[0]

nBH = int(1/dx)
print(f"Grid size: {nx}, dx: {dx}, resolution at BH: {nBH}")
# Out:
# Grid size: 769, dx: 0.010416666666666666, resolution at BH: 96

# %%
derivs = [ 
    DerivType.D1_KP4,
    DerivType.D1_ME44,
    DerivType.D1_ME642,
    DerivType.D1_JT4,
    DerivType.D1_JT6,
    DerivType.D1_JP6,
    DerivType.D1_DSQ6A,
    DerivType.D1_DSQ6B,
    DerivType.D1_DSQ6B_LEFT,
    DerivType.D1_DSQ6B_RIGHT
]
dnames = [ 
    "D1_KP4",
    "D1_ME44",
    "D1_ME642",
    "D1_JT4",
    "D1_JT6",
    "D1_JP6",
    "D1_DSQ6A",
    "D1_DSQ6B",
    "D1_DSQ6B_LEFT",
    "D1_DSQ6B_RIGHT"
]

derivs2 = [
    DerivType.D2_ME44,
    DerivType.D2_ME642,
    DerivType.D2_JT4,
    DerivType.D2_JP6,
    DerivType.D2_DSQ6A,
    DerivType.D2_DSQ6B
]

dnames2 = [
    "D2_ME44",
    "D2_ME642",
    "D2_JT4",
    "D2_JP6",
    "D2_DSQ6A",
    "D2_DSQ6B"
]

# %%
f, dxf, dxxf = func3(x)

# %%
# create data files
d1_data = []

for dd, dn in zip(derivs, dnames):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.deriv(x, dd, CFDSolve.SCIPY)
    CDxf = CD.grad(f)
    err = np.abs(CDxf - dxf)
    d1_data.append([dn, CDxf, err])
# Out:
# ...constructing D1_KP4
# ...constructing D1_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME44.  Using D_LU instead.
# ...constructing D1_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME642.  Using D_LU instead.
# ...constructing D1_JT4
# ...constructing D1_JT6
# ...constructing D1_JP6
# ...constructing D1_DSQ6A
# ...constructing D1_DSQ6B
# ...constructing D1_DSQ6B_LEFT
# ...constructing D1_DSQ6B_RIGHT
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning: divide by zero encountered in matmul
#   rhs = np.matmul(self.Q, f) * self.denom
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning: overflow encountered in matmul
#   rhs = np.matmul(self.Q, f) * self.denom
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning: invalid value encountered in matmul
#   rhs = np.matmul(self.Q, f) * self.denom
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning: divide by zero encountered in matmul
#   dxf = np.matmul(self.D, f) * self.denom
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning: overflow encountered in matmul
#   dxf = np.matmul(self.D, f) * self.denom
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning: invalid value encountered in matmul
#   dxf = np.matmul(self.D, f) * self.denom

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d1_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Derivative Error Plots (dxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_KP4',
#               'type': 'scatter',
#               'uid': 'ce868aa6-e032-46b3-805f-75710c153805',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAgBjs4D0AAAAAnn+9PQAAAADgAq' ... 'AATH6qPQAAAAAoF749AAAAQF9Q4T0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME44',
#               'type': 'scatter',
#               'uid': '4925924a-c6c2-491e-bafe-0b41a2befc0d',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAgOh34z0AAAAAGYbDPQAAAAB0F7' ... 'AAwBW6PZyJZKJhFdA/Zqpa7e3/zz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME642',
#               'type': 'scatter',
#               'uid': 'f79468e8-2ff2-4f7d-ac29-096cbead3085',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'pq9yrQP6xZHDplFdA/ZvI2mN//zz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT4',
#               'type': 'scatter',
#               'uid': '882adac7-81ca-4549-82aa-8e1c75fa8578',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAACeJ3D0AAAAAWi65PQAAAABse6' ... 'AAlHyoPQAAAAAkMbk9AAAAgKCL3D0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT6',
#               'type': 'scatter',
#               'uid': '92fda252-2432-4c71-85aa-0a16e4688a5e',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAICuUj0AAAAAAGgqPQAAAAAAAB' ... 'AAANQmPQAAAAAAwjo9AAAAAMC7Yj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JP6',
#               'type': 'scatter',
#               'uid': '9787f714-290c-4cb4-aefb-24323dcd03ad',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('QFw0eWdlfz+AqtUThzFWPwB/SJMzUk' ... 'YPIFJBP4B/WRNuMVY/AN+5GkRlfz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6A',
#               'type': 'scatter',
#               'uid': '00b3d46d-bc3a-4d3e-b189-0091b1cc683a',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'AAwBW6PQAApJEMvqw+AADNM+OqvD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B',
#               'type': 'scatter',
#               'uid': 'da7c49bc-ca5f-43ac-bac8-e62f3817e388',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'AAwBW6PQAApJEMvqw+AADNM+OqvD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_LEFT',
#               'type': 'scatter',
#               'uid': '673319f4-7063-4a52-b229-0a69e7e75d3f',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('UnhrM4IV0D8AAGSqTb6sPgDGDfp+wU' ... 'PgWcFFPwAApJEMvqw+NLmW/G8V0D8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_RIGHT',
#               'type': 'scatter',
#               'uid': '6b5d5197-7b43-4b4d-99a2-d4022792f435',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAM4zPvi8PgAAAABG08' ... 'AAQNLDPQAAbnb897w+AADNM+OqvD4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Derivative Error Plots (dxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })

# %%
# create data files
d2_data = []

for dd, dn in zip(derivs2, dnames2):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.deriv(x, dd, CFDSolve.SCIPY)
    CDxxf = CD.grad(f)
    err = np.abs(CDxxf - dxxf)
    d2_data.append([dn, CDxxf, err])
# Out:
# ...constructing D2_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D2_ME44.  Using D_LU instead.
# ...constructing D2_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D2_ME642.  Using D_LU instead.
# ...constructing D2_JT4
# ...constructing D2_JP6
# ...constructing D2_DSQ6A
# ...constructing D2_DSQ6B
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# divide by zero encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# overflow encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# invalid value encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# divide by zero encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# overflow encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# invalid value encountered in matmul

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d2_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Derivative Error Plots (dxxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_ME44',
#               'type': 'scatter',
#               'uid': '695b46bb-ae00-4350-a099-75beb215fa4a',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAsNunDD4AAACA3rzVPQAAAABMEq' ... 'AAQNmtPQAAAIAmZdU9AAAA2JRqDD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_ME642',
#               'type': 'scatter',
#               'uid': 'fb29a206-21ec-4af6-81c1-e57dd0fd955d',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AIDdbi/W0z4AAOhNi9GcPgAAAABMEq' ... 'AAQNmtPQAAaFI50Zw+AMCmFPjV0z4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_JT4',
#               'type': 'scatter',
#               'uid': '2bc5d0a2-0e2e-43ed-adc7-23ac99d21ce3',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAYJaEEz4AAACAUmjePQAAAAAiqb' ... 'CAS9bDPQAAAFD/QfU9AAAAU4isKj4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_JP6',
#               'type': 'scatter',
#               'uid': '2f77b257-409e-41e9-9898-8ac87421ffa2',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('sJ0yK7F3gD8AEquZHKZGPwAsMV1i9y' ... 'q+RfcgP4C9D2n2pUY/aITpYZV3gD8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_DSQ6A',
#               'type': 'scatter',
#               'uid': '73a3d09e-ebc5-4be5-8351-3f424b2e9dc9',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AIDdbi/W0z4AAOhNi9GcPgAAAABMEq' ... 'AAQNmtPQAAaFI50Zw+AMCmFPjV0z4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D2_DSQ6B',
#               'type': 'scatter',
#               'uid': '2a69ff17-b6ba-4f33-a10a-928b6eb0cd43',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AIDdbi/W0z4AAOhNi9GcPgAAAABMEq' ... 'AAQNmtPQAAaFI50Zw+AMCmFPjV0z4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Derivative Error Plots (dxxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })

# %%
x_bh = 0.0
dx_bh = 0.15

d3_data = []

for dd, dn in zip(derivs, dnames):
    print(f"...constructing {dn}")
    CD = NCompactDerivative.bh_deriv(x, dd, DerivType.D1_ME44, CFDSolve.SCIPY, x_bh, dx_bh)
    CDxf = CD.grad(f)
    err = np.abs(CDxf - dxf)
    d3_data.append([dn, CDxf, err])
# Out:
# ...constructing D1_KP4
# ...constructing D1_ME44
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME44.  Using D_LU instead.
# ...constructing D1_ME642
# Method CFDSolve.SCIPY not supported for explicit derivatives of type DerivType.D1_ME642.  Using D_LU instead.
# ...constructing D1_JT4
# ...constructing D1_JT6
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# divide by zero encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# overflow encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:207: RuntimeWarning:
#
# invalid value encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# divide by zero encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# overflow encountered in matmul
#
# /Users/dave/projects/pynwave2d/tests/../nwave/cd.py:205: RuntimeWarning:
#
# invalid value encountered in matmul
# ...constructing D1_JP6
# ...constructing D1_DSQ6A
# ...constructing D1_DSQ6B
# ...constructing D1_DSQ6B_LEFT
# ...constructing D1_DSQ6B_RIGHT

# %%
fig = go.FigureWidget()
fig.layout.hovermode = 'closest'
fig.layout.hoverdistance = -1 #ensures no "gaps" for selecting sparse data
default_linewidth = 2
highlighted_linewidth_delta = 2

# just some traces with random data points  
num_of_traces = len(derivs)

for dd in d3_data:
    trace = go.Scatter(
        x=x, 
        y=dd[2], 
        mode='lines+markers', 
        name=dd[0], 
        line={ 'width': default_linewidth },
        hoverinfo='skip'
    )
    fig.add_trace(trace)

fig.add_vline(x=-0.5, line_width=1)
fig.add_vline(x=0.5, line_width=1)
fig.add_vrect(x0=-0.5, x1=0.5, line_width=0, fillcolor="gray", opacity=0.2)

# our custom event handler
def update_trace(trace, points, selector):
    # this list stores the points which were clicked on
    # in all but one trace they are empty
    if len(points.point_inds) == 0:
        return
        
    for i,_ in enumerate(f.data):
        fig.data[i]['line']['width'] = default_linewidth + highlighted_linewidth_delta * (i == points.trace_index)


# we need to add the on_click event to each trace separately       
for i in range( len(fig.data) ):
    fig.data[i].on_click(update_trace)

# Layout with log scale option
fig.update_layout(
    title='Masked BH Derivative Error Plots (dxf)',
    xaxis=dict(title='x', type='linear'),  # use 'log' for log scale
    yaxis=dict(title='y', type='log'),
    hovermode='x',
    template='plotly_white'
)

# let's show the figure 
fig.show()
# Out:
# FigureWidget({
#     'data': [{'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_KP4',
#               'type': 'scatter',
#               'uid': 'e844b3e8-9309-437b-94b3-d97afd0284f7',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAgBjs4D0AAAAAnn+9PQAAAADgAq' ... 'AATH6qPQAAAAAoF749AAAAQF9Q4T0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME44',
#               'type': 'scatter',
#               'uid': 'b87453d2-bc50-4dc9-a79c-73d602a00a3e',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAgOh34z0AAAAAGYbDPQAAAAB0F7' ... 'AAwBW6PZyJZKJhFdA/Zqpa7e3/zz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_ME642',
#               'type': 'scatter',
#               'uid': '6fa94ebb-5498-4a16-9663-40c5b626ccd1',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'pq9yrQP6xZHDplFdA/ZvI2mN//zz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT4',
#               'type': 'scatter',
#               'uid': '121da19e-cd60-4b2d-b7cb-8c647e88dab0',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAACeJ3D0AAAAAWi65PQAAAABse6' ... 'AAlHyoPQAAAAAkMbk9AAAAgKCL3D0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JT6',
#               'type': 'scatter',
#               'uid': 'dcf50136-1c95-470e-9308-5cda381327e6',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AAAAAICuUj0AAAAAAGgqPQAAAAAAAB' ... 'AAANQmPQAAAAAAwjo9AAAAAMC7Yj0='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_JP6',
#               'type': 'scatter',
#               'uid': 'e1053243-9226-47f7-9bf0-aac838791ced',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('QFw0eWdlfz+AqtUThzFWPwB/SJMzUk' ... 'YPIFJBP4B/WRNuMVY/AN+5GkRlfz8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6A',
#               'type': 'scatter',
#               'uid': '9f3c4b7b-161f-4531-bf50-d63dcef2f556',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'AAwBW6PQAApJEMvqw+AADNM+OqvD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B',
#               'type': 'scatter',
#               'uid': '57f34933-9fbf-4ee3-bced-83a5e3c58c2a',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAGSqTb6sPgAAAAB0F7' ... 'AAwBW6PQAApJEMvqw+AADNM+OqvD4='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_LEFT',
#               'type': 'scatter',
#               'uid': 'a3ea5072-deac-4314-97de-cd1ca5fd5781',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('UnhrM4IV0D8AAGSqTb6sPgDGDfp+wU' ... 'PgWcFFPwAApJEMvqw+NLmW/G8V0D8='),
#                     'dtype': 'f8'}},
#              {'hoverinfo': 'skip',
#               'line': {'width': 2},
#               'mode': 'lines+markers',
#               'name': 'D1_DSQ6B_RIGHT',
#               'type': 'scatter',
#               'uid': 'e5cbea1d-a4cb-43d1-9acf-ba47888bd122',
#               'x': {'bdata': ('AAAAAAAAEMCrqqqqquoPwFVVVVVV1Q' ... 'VVVdUPQKqqqqqq6g9AAAAAAAAAEEA='),
#                     'dtype': 'f8'},
#               'y': {'bdata': ('AADEGSSrvD4AAM4zPvi8PgAAAABG08' ... 'AAQNLDPQAAbnb897w+AADNM+OqvD4='),
#                     'dtype': 'f8'}}],
#     'layout': {'hoverdistance': -1,
#                'hovermode': 'x',
#                'shapes': [{'line': {'width': 1},
#                            'type': 'line',
#                            'x0': -0.5,
#                            'x1': -0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'line': {'width': 1},
#                            'type': 'line',
#                            'x0': 0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'},
#                           {'fillcolor': 'gray',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': -0.5,
#                            'x1': 0.5,
#                            'xref': 'x',
#                            'y0': 0,
#                            'y1': 1,
#                            'yref': 'y domain'}],
#                'template': '...',
#                'title': {'text': 'Masked BH Derivative Error Plots (dxf)'},
#                'xaxis': {'title': {'text': 'x'}, 'type': 'linear'},
#                'yaxis': {'title': {'text': 'y'}, 'type': 'log'}}
# })
